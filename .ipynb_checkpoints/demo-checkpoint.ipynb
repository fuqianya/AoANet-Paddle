# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# We use this image as an example
img = Image.open('data/COCO_val2014_000000573223.jpg')
plt.imshow(img)
plt.show()
# Run prediction
# !python predict.py --model log/log_aoa_rl/model.pdparams --infos_path log/log_aoa_rl/infos_aoa.pkl
# Out:
# assigned 113287 images to split train
# assigned 5000 images to split val
# assigned 5000 images to split test
# W0105 17:14:14.995714 29714 device_context.cc:447] Please NOTE: device: 0, GPU Compute Capability: 8.6, Driver API Version: 11.5, Runtime API Version: 11.1
# W0105 17:14:14.997367 29714 device_context.cc:465] device: 0, cuDNN Version: 8.0.
# W0105 17:14:17.166050 29714 device_context.h:397] WARNING: device: 0. The installed Paddle is compiled with CUDNN 8.1, but CUDNN version in your machine is 8.0, which may cause serious incompatible bug. Please recompile or reinstall Paddle with compatible CUDNN version.
# /home/fuqian/Downloads/Software/anaconda3-2021.04/envs/2020-Oscar-ECCV/lib/python3.7/site-packages/paddle/tensor/creation.py:130: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# ...
